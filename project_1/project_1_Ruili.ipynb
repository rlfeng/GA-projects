# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# How can the College Board increase the SAT participation rate in Wisconsin?

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import pandas as pd
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style('whitegrid')

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code:
sat_2017= pd.read_csv('./sat_2017.csv')
act_2017= pd.read_csv('./act_2017.csv')
sat_2018= pd.read_csv('./sat_2018.csv')
act_2018_updated= pd.read_csv('./act_2018_updated.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
sat_2017.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
act_2017.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %%
sat_2018.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            6%                                 595
# 1                Alaska           43%                                 562
# 2               Arizona           29%                                 577
# 3              Arkansas            5%                                 592
# 4            California           60%                                 540
# 5              Colorado          100%                                 519
# 6           Connecticut          100%                                 535
# 7              Delaware          100%                                 505
# 8  District of Columbia           92%                                 497
# 9               Florida           56%                                 550
#
#    Math  Total
# 0   571   1166
# 1   544   1106
# 2   572   1149
# 3   576   1169
# 4   536   1076
# 5   506   1025
# 6   519   1053
# 7   492    998
# ...

# %%
act_2018_updated.head(10)
# Out:
#                   State  Percentage of Students Tested  \
# 0               Alabama                            100
# 1                Alaska                             33
# 2               Arizona                             66
# 3              Arkansas                            100
# 4            California                             27
# 5              Colorado                             30
# 6           Connecticut                             26
# 7              Delaware                             17
# 8  District of Columbia                             32
# 9               Florida                             66
#
#    Average Composite Score  Average English Score  Average Math Score  \
# 0                     19.1                   18.9                18.3
# 1                     20.8                   19.8                20.6
# 2                     19.2                   18.2                19.4
# 3                     19.4                   19.1                18.9
# ...

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# For SAT:
# 1) Both 2017 and 2018 have the same set of categories and number of rows(or states).
# 2) 'Total' is equals to the sum of 'Evidence-Based Reading and Writing' and 'Math'.
# 3) The ranking of rows is arranged according to alphabetical order of 'State'.
#
# For ACT:
# 1) Both 2017 and 2018 have the similar set of categories and number of rows(or states).
# 2) 'Composite' should be equal to the average of English, Math, Reading and Science Scores.
# 3) The ranking of rows is arranged according to alphabetical order of 'State'.

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# The data look complete with no missing values.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# For SAT, there are two big sections—Evidence-Based Reading and Writing (EBRW), and Math, with a scaled score of between 200 and 800 points on each section, for a total of 1600 possible points on the SAT. The minimum and maximum possible value for each section are 200 and 800 points respectively.
#
# For ACT, there are 4 sections on the ACT: English, Math, Reading, and Science. Each section is scored out of 36 points. The minimum and maximum possible value for each section are 0 and 36 points respectively.

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
# Screen data for potential errors in ACT 2017
act_2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %%
# Screen data for potential errors in SAT 2017
sat_2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
# To correct a typo in the ACT 2017 Science score for Maryland
act_2017=act_2017.replace(2.3,23.2)

# %%
# To correct a typo in the SAT 2017 Math score for Maryland
sat_2017=sat_2017.replace(52,524)

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null object
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null object
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null object
# dtypes: float64(4), object(3)
# memory usage: 2.9+ KB

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# 1) The 'Participation' column in both SAT and ACT tests should be "float64" instead of "object".
# 2) The "Composite" column in ACT should be "float64" instead of "object".
# 3) ACT data have one more row than SAT data.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null object
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null object
# dtypes: float64(4), object(3)
# memory usage: 2.9+ KB

# %%
def participation(string):
    participation_number = float(string[:-1])/100
    return participation_number

sat_2017['Participation'] = sat_2017['Participation'].map(lambda x: participation(x))
act_2017['Participation'] = act_2017['Participation'].map(lambda x: participation(x))

# %%
act_2017['Composite']=act_2017.Composite.str.replace('x','').astype(float)

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null float64
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null float64
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null float64
# dtypes: float64(6), object(1)
# memory usage: 2.9+ KB

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
sat_2017=sat_2017.rename(columns={"Participation": "SAT(2017) Participation", "Evidence-Based Reading and Writing": "SAT(2017) Reading and Writing",
                         "Math":"SAT(2017) Math","Total":"SAT(2017) Total"});

# %%
act_2017=act_2017.rename(columns={"Participation": "ACT(2017) Participation", "English": "ACT(2017) English",
                         "Math":"ACT(2017) Math","Reading":"ACT(2017) Reading",
                         "Science":"ACT(2017) Science","Composite":"ACT(2017) Composite"});

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|ACT/SAT|US state|
# |SAT(2017) Participation |float|SAT|2017 SAT participation rate in US state|
# |SAT(2017) Reading and Writing|int|SAT|2017 SAT Reading and Writing Score in US state|
# |SAT(2017) Math|int|SAT|2017 SAT Math Score in US state|
# |SAT(2017) Total|int|SAT|2017 SAT Total Score in US state|
# |ACT(2017) Participation|float|ACT|2017 ACT participation rate in US state|
# |ACT(2017) English|float|ACT|2017 ACT English score in US state|
# |ACT(2017) Math|float|ACT|2017 ACT Math score in US state|
# |ACT(2017) Reading|float|ACT|2017 ACT Reading score in US state|
# |ACT(2017) Science|float|ACT|2017 ACT Science score in US state|
# |ACT(2017) Composite|float|ACT|2017 ACT Composite score in US state|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
#The ACT dataframe contains a row with national averages.  This can be removed.
act_2017.drop(0,inplace=True)

#Keeps the index lined up with the SAT dataframe index.
act_2017.reset_index(drop=True,inplace=True)

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
combined_2017=pd.merge(act_2017,sat_2017,how='left')

# %%
combined_2017.head()
# Out:
#         State  ACT(2017) Participation  ACT(2017) English  ACT(2017) Math  \
# 0     Alabama                     1.00               18.9            18.4
# 1      Alaska                     0.65               18.7            19.8
# 2     Arizona                     0.62               18.6            19.8
# 3    Arkansas                     1.00               18.9            19.0
# 4  California                     0.31               22.5            22.7
#
#    ACT(2017) Reading  ACT(2017) Science  ACT(2017) Composite  \
# 0               19.7               19.4                 19.2
# 1               20.4               19.9                 19.8
# 2               20.1               19.8                 19.7
# 3               19.7               19.5                 19.4
# 4               23.1               22.2                 22.8
#
#    SAT(2017) Participation  SAT(2017) Reading and Writing  SAT(2017) Math  \
# 0                     0.05                            593             572
# ...

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
combined_2017.to_csv('combined_2017.csv',index=False)

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
act_2018_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
# State                            51 non-null object
# Percentage of Students Tested    51 non-null int64
# Average Composite Score          51 non-null float64
# Average English Score            51 non-null float64
# Average Math Score               51 non-null float64
# Average Reading Score            51 non-null float64
# Average Science Score            51 non-null float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 2.9+ KB

# %%
# Convert 'Participation' type to float
act_2018_updated['Percentage of Students Tested']=act_2018_updated['Percentage of Students Tested'].astype(float)*(1/100)

# %%
# Change column names for ACT 2018
act_2018_updated=act_2018_updated.rename(columns={"Percentage of Students Tested": "ACT(2018) Participation", "Average English Score": "ACT(2018) English",
                         "Average Math Score":"ACT(2018) Math","Average Reading Score":"ACT(2018) Reading",
                         "Average Science Score":"ACT(2018) Science","Average Composite Score":"ACT(2018) Composite"});

# %%
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null object
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
# Convert 'Participation' type to float
sat_2018['Participation']=sat_2018.Participation.str.replace('%','').astype(float)*(1/100)

# %%
# Change column names for SAT 2018

sat_2018=sat_2018.rename(columns={"Participation": "SAT(2018) Participation", "Evidence-Based Reading and Writing": "SAT(2018) Reading and Writing",
                         "Math":"SAT(2018) Math","Total":"SAT(2018) Total"});

# %%
#Combine 2018 SAT and ACT test scores
combined_2018=pd.merge(act_2018_updated,sat_2018,how='left')
combined_2018.head()
# Out:
#         State  ACT(2018) Participation  ACT(2018) Composite  \
# 0     Alabama                     1.00                 19.1
# 1      Alaska                     0.33                 20.8
# 2     Arizona                     0.66                 19.2
# 3    Arkansas                     1.00                 19.4
# 4  California                     0.27                 22.7
#
#    ACT(2018) English  ACT(2018) Math  ACT(2018) Reading  ACT(2018) Science  \
# 0               18.9            18.3               19.6               19.0
# 1               19.8            20.6               21.6               20.7
# 2               18.2            19.4               19.5               19.2
# 3               19.1            18.9               19.7               19.4
# 4               22.5            22.5               23.0               22.1
#
#    SAT(2018) Participation  SAT(2018) Reading and Writing  SAT(2018) Math  \
# 0                     0.06                            595             571
# ...

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
#Combine 2017 and 2017 SAT and ACT tests scores
final=pd.merge(combined_2017,combined_2018,how='left')
final.head()
# Out:
#         State  ACT(2017) Participation  ACT(2017) English  ACT(2017) Math  \
# 0     Alabama                     1.00               18.9            18.4
# 1      Alaska                     0.65               18.7            19.8
# 2     Arizona                     0.62               18.6            19.8
# 3    Arkansas                     1.00               18.9            19.0
# 4  California                     0.31               22.5            22.7
#
#    ACT(2017) Reading  ACT(2017) Science  ACT(2017) Composite  \
# 0               19.7               19.4                 19.2
# 1               20.4               19.9                 19.8
# 2               20.1               19.8                 19.7
# 3               19.7               19.5                 19.4
# 4               23.1               22.2                 22.8
#
#    SAT(2017) Participation  SAT(2017) Reading and Writing  SAT(2017) Math  \
# 0                     0.05                            593             572
# ...

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 21 columns):
# State                            51 non-null object
# ACT(2017) Participation          51 non-null float64
# ACT(2017) English                51 non-null float64
# ACT(2017) Math                   51 non-null float64
# ACT(2017) Reading                51 non-null float64
# ACT(2017) Science                51 non-null float64
# ACT(2017) Composite              51 non-null float64
# SAT(2017) Participation          51 non-null float64
# SAT(2017) Reading and Writing    51 non-null int64
# SAT(2017) Math                   51 non-null int64
# SAT(2017) Total                  51 non-null int64
# ACT(2018) Participation          51 non-null float64
# ACT(2018) Composite              51 non-null float64
# ACT(2018) English                51 non-null float64
# ACT(2018) Math                   51 non-null float64
# ACT(2018) Reading                51 non-null float64
# ...

# %%
final.to_csv('final.csv',index=False)

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
final.describe().transpose()
# Out:
#                                count         mean        std     min  \
# ACT(2017) Participation         51.0     0.652549   0.321408    0.08
# ACT(2017) English               51.0    20.931373   2.353677   16.30
# ACT(2017) Math                  51.0    21.182353   1.981989   18.00
# ACT(2017) Reading               51.0    22.013725   2.067271   18.10
# ACT(2017) Science               51.0    21.450980   1.739353   18.20
# ACT(2017) Composite             51.0    21.519608   2.020695   17.80
# SAT(2017) Participation         51.0     0.398039   0.352766    0.02
# SAT(2017) Reading and Writing   51.0   569.117647  45.666901  482.00
# SAT(2017) Math                  51.0   556.882353  47.121395  468.00
# SAT(2017) Total                 51.0  1126.098039  92.494812  950.00
# ACT(2018) Participation         51.0     0.616471   0.340810    0.07
# ACT(2018) Composite             51.0    21.486275   2.106278   17.70
# ACT(2018) English               51.0    20.988235   2.446356   16.60
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
def std_dev(col):
        n=len(col)
        average_mean=sum(col)/n    
        sd=0
        
        for i in col:
            sd += (i - average_mean)**2
        
        sd = (sd /(n-1))**0.5
        
        return sd

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
{col.name:std_dev(col) for col in [final[i] for i in final.columns if (final[i].dtype=='float64') or (final[i].dtype=='int64')]}
# Out:
# {'ACT(2017) Participation': 0.32140842015886834,
#  'ACT(2017) English': 2.35367713980303,
#  'ACT(2017) Math': 1.9819894936505533,
#  'ACT(2017) Reading': 2.0672706264873146,
#  'ACT(2017) Science': 1.7393530462812443,
#  'ACT(2017) Composite': 2.020694891154341,
#  'SAT(2017) Participation': 0.35276632270013036,
#  'SAT(2017) Reading and Writing': 45.66690138768932,
#  'SAT(2017) Math': 47.12139516560329,
#  'SAT(2017) Total': 92.49481172519046,
#  'ACT(2018) Participation': 0.3408097623567245,
#  'ACT(2018) Composite': 2.1062781969951776,
#  'ACT(2018) English': 2.4463562339793055,
#  'ACT(2018) Math': 2.035764538177723,
#  'ACT(2018) Reading': 2.1672445684804105,
#  'ACT(2018) Science': 1.8701137639716146,
#  'SAT(2018) Participation': 0.37314256330391965,
#  'SAT(2018) Reading and Writing': 47.50262737831599,
#  'SAT(2018) Math': 47.77262322095955,
#  'SAT(2018) Total': 94.15508275097599}

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %%
#Manual calculated standard deviation
std_dev(final['ACT(2017) Participation'])
# Out:
# 0.32140842015886834

# %%
#Standard deviation from numpy's std method
np.std(final['ACT(2017) Participation'])
# Out:
# 0.3182417575123181

# %% [markdown]
# The manually calculated standard deviation gives the same value as pandas describe. However, it is different from numpy's std output as numpy's method uses sd = (sd /n)**0.5, instead of sd = (sd /(n-1))**0.5.

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# Key trends for states with >50% participation on both test either year:
# 1)In 2017, Florida, Georgia and Hawaii had no mandatory testing for either of the tests.
# 2) In 2018, North Carolina and South Carolina had slight increase in their SAT participation rates.

# %%
# States with >50% participation on both SAT and ACT tests in 2017

final.loc[(final['SAT(2017) Participation']>0.5) & (final['ACT(2017) Participation']>0.5), 'State']
# Out:
# 9     Florida
# 10    Georgia
# 11     Hawaii
# Name: State, dtype: object

# %%
# States with >50% participation on both SAT and ACT tests in 2018

final.loc[(final['SAT(2018) Participation']>0.5) & (final['ACT(2018) Participation']>0.5), 'State']
# Out:
# 9            Florida
# 10           Georgia
# 11            Hawaii
# 33    North Carolina
# 40    South Carolina
# Name: State, dtype: object

# %% [markdown]
# Key trends for states with >50% participation on both test either year:
# 1)In 2017, Florida, Georgia and Hawaii had no mandatory testing for either of the tests.

# %% [markdown]
# Key trends in changes to 100% SAT and ACT participation rates:
# Due to changes in the government policy, several states had made SAT (e.g. Colorado) and ACT (e.g. Nebraska, Ohio) mandatory.

# %%
#Change in states with 100% SAT Participation in 2017 and 2018
SAT_2017_fullPar=final.loc[(final['SAT(2017) Participation']==1.0),'State']
SAT_2018_fullPar=final.loc[(final['SAT(2018) Participation']==1.0),'State']
SAT_2018_drop=list(set(SAT_2017_fullPar) - set(SAT_2018_fullPar))
SAT_2017_drop=list(set(SAT_2018_fullPar) - set(SAT_2017_fullPar))

print('States that have 100% SAT participation in 2017 but not in 2018:',format(SAT_2018_drop))
print('States that have 100% SAT participate in 2018 but not in 2017:',format(SAT_2017_drop))
# Out:
# States that have 100% SAT participation in 2017 but not in 2018: ['District of Columbia']
# States that have 100% SAT participate in 2018 but not in 2017: ['Colorado', 'Idaho']

# %%
#Change in states with 100% ACT Participation in 2017 and 2018

ACT_2017_fullPar=final.loc[(final['ACT(2017) Participation']==1.0),'State'].tolist() 
ACT_2018_fullPar=final.loc[(final['ACT(2018) Participation']==1.0),'State'].tolist() 

ACT_2018_drop=list(set(ACT_2017_fullPar) - set(ACT_2018_fullPar))
ACT_2017_drop=list(set(ACT_2018_fullPar) - set(ACT_2017_fullPar))

print('States that have 100% ACT participation in 2017 but not in 2018:',format(ACT_2018_drop))
print('States that have 100% ACT participate in 2018 but not in 2017:',format(ACT_2017_drop))
# Out:
# States that have 100% ACT participation in 2017 but not in 2018: ['Minnesota', 'Colorado']
# States that have 100% ACT participate in 2018 but not in 2017: ['Ohio', 'Nebraska']

# %% [markdown]
# Key trends (Participation)
#
# 1) In 2017 and 2018, ACT appeared to have higher participation rate in the US.
# 2) SAT has lower minimum participation rate than ACT.
# 3) ACT has more states with 100% participation rate than SAT.
#
# Key trends (Scores)
# 1) In 2017 and 2018, there is a negative correlation between participation rate and score for both SAT and ACT.

# %%
#2017 SAT Top States

final.sort_values('SAT(2017) Participation', ascending=False)[['State','SAT(2017) Participation']].head(5)
# Out:
#                    State  SAT(2017) Participation
# 8   District of Columbia                     1.00
# 22              Michigan                     1.00
# 6            Connecticut                     1.00
# 7               Delaware                     1.00
# 29         New Hampshire                     0.96

# %%
#2018 SAT Top States

final.sort_values('SAT(2018) Participation', ascending=False)[['State','SAT(2018) Participation']].head(6)
# Out:
#           State  SAT(2018) Participation
# 5      Colorado                     1.00
# 6   Connecticut                     1.00
# 7      Delaware                     1.00
# 22     Michigan                     1.00
# 12        Idaho                     1.00
# 19        Maine                     0.99

# %%
#2017 SAT Bottom States
final.sort_values('SAT(2017) Participation', ascending=False)[['State','SAT(2017) Participation']].tail(5)
# Out:
#            State  SAT(2017) Participation
# 3       Arkansas                     0.03
# 50       Wyoming                     0.03
# 34  North Dakota                     0.02
# 24   Mississippi                     0.02
# 15          Iowa                     0.02

# %%
#2018 SAT Bottom States
final.sort_values('SAT(2018) Participation', ascending=False)[['State','SAT(2018) Participation']].tail(5)
# Out:
#            State  SAT(2018) Participation
# 24   Mississippi                     0.03
# 15          Iowa                     0.03
# 49     Wisconsin                     0.03
# 50       Wyoming                     0.03
# 34  North Dakota                     0.02

# %%
plot_2018_SAT=final.sort_values('SAT(2018) Participation', ascending=False)[['State','SAT(2018) Participation']].tail(4)
sns.set_color_codes("pastel")
sns.barplot(x="State", y="SAT(2018) Participation", data=plot_2018_SAT,
            label="Total", color="b").set_title("States with lowest SAT(2018) participation rates")
# Out:
# Text(0.5, 1.0, 'States with lowest SAT(2018) participation rates')

# %%
#2017 ACT Top States

final.sort_values('ACT(2017) Participation', ascending=False)[['State','ACT(2017) Participation']].head(18)
# Out:
#              State  ACT(2017) Participation
# 0          Alabama                     1.00
# 17        Kentucky                     1.00
# 49       Wisconsin                     1.00
# 44            Utah                     1.00
# 42       Tennessee                     1.00
# 40  South Carolina                     1.00
# 36        Oklahoma                     1.00
# 33  North Carolina                     1.00
# 28          Nevada                     1.00
# 26         Montana                     1.00
# 24     Mississippi                     1.00
# 23       Minnesota                     1.00
# 18       Louisiana                     1.00
# 25        Missouri                     1.00
# 50         Wyoming                     1.00
# 5         Colorado                     1.00
# 3         Arkansas                     1.00
# 34    North Dakota                     0.98

# %%
#2018 ACT Top States

final.sort_values('ACT(2018) Participation', ascending=False)[['State','ACT(2018) Participation']].head(18)
# Out:
#              State  ACT(2018) Participation
# 0          Alabama                     1.00
# 17        Kentucky                     1.00
# 49       Wisconsin                     1.00
# 44            Utah                     1.00
# 42       Tennessee                     1.00
# 40  South Carolina                     1.00
# 36        Oklahoma                     1.00
# 35            Ohio                     1.00
# 33  North Carolina                     1.00
# 28          Nevada                     1.00
# 27        Nebraska                     1.00
# 26         Montana                     1.00
# 24     Mississippi                     1.00
# 18       Louisiana                     1.00
# 25        Missouri                     1.00
# 50         Wyoming                     1.00
# 3         Arkansas                     1.00
# 23       Minnesota                     0.99

# %%
#2017 ACT Bottom States

final.sort_values('ACT(2017) Participation', ascending=False)[['State','ACT(2017) Participation']].tail(5)
# Out:
#             State  ACT(2017) Participation
# 38   Pennsylvania                     0.23
# 39   Rhode Island                     0.21
# 7        Delaware                     0.18
# 29  New Hampshire                     0.18
# 19          Maine                     0.08

# %%
#2018 ACT Bottom States

final.sort_values('ACT(2018) Participation', ascending=False)[['State','ACT(2018) Participation']].tail(5)
# Out:
#             State  ACT(2018) Participation
# 38   Pennsylvania                     0.20
# 7        Delaware                     0.17
# 29  New Hampshire                     0.16
# 39   Rhode Island                     0.15
# 19          Maine                     0.07

# %%
#2017 ACT States highest in Composite score
final.sort_values('ACT(2017) Composite', ascending=False)[['State','ACT(2017) Composite']].head(5)
# Out:
#                    State  ACT(2017) Composite
# 29         New Hampshire                 25.5
# 21         Massachusetts                 25.4
# 6            Connecticut                 25.2
# 19                 Maine                 24.3
# 8   District of Columbia                 24.2

# %%
#2018 ACT States highest in Composite score
final.sort_values('ACT(2018) Composite', ascending=False)[['State','ACT(2018) Composite']].head(5)
# Out:
#             State  ACT(2018) Composite
# 6     Connecticut                 25.6
# 21  Massachusetts                 25.5
# 29  New Hampshire                 25.1
# 32       New York                 24.5
# 22       Michigan                 24.4

# %%
#2017 ACT States lowest in Composite score
final.sort_values('ACT(2017) Composite', ascending=False)[['State','ACT(2017) Composite']].tail(5)
# Out:
#              State  ACT(2017) Composite
# 33  North Carolina                 19.1
# 11          Hawaii                 19.0
# 40  South Carolina                 18.7
# 24     Mississippi                 18.6
# 28          Nevada                 17.8

# %%
#2018 ACT States lowest in Composite score
final.sort_values('ACT(2018) Composite', ascending=False)[['State','ACT(2018) Composite']].tail(5)
# Out:
#              State  ACT(2018) Composite
# 0          Alabama                 19.1
# 11          Hawaii                 18.9
# 24     Mississippi                 18.6
# 40  South Carolina                 18.3
# 28          Nevada                 17.7

# %%
#2017 SAT Top States in Total
final.sort_values('SAT(2017) Total', ascending=False)[['State','SAT(2017) Total']].head(5)
# Out:
#         State  SAT(2017) Total
# 23  Minnesota             1295
# 49  Wisconsin             1291
# 15       Iowa             1275
# 25   Missouri             1271
# 16     Kansas             1260

# %%
#2018 SAT Top States in Total
final.sort_values('SAT(2018) Total', ascending=False)[['State','SAT(2018) Total']].head(5)
# Out:
#            State  SAT(2018) Total
# 23     Minnesota             1298
# 49     Wisconsin             1294
# 34  North Dakota             1283
# 15          Iowa             1265
# 16        Kansas             1265

# %%
#2017 SAT Bottom States in Total
final.sort_values('SAT(2017) Total', ascending=False)[['State','SAT(2017) Total']].tail(5)
# Out:
#                    State  SAT(2017) Total
# 19                 Maine             1012
# 12                 Idaho             1005
# 22              Michigan             1005
# 7               Delaware              996
# 8   District of Columbia              950

# %%
#2018 SAT Bottom States in Total
final.sort_values('SAT(2018) Total', ascending=False)[['State','SAT(2018) Total']].tail(5)
# Out:
#                    State  SAT(2018) Total
# 11                Hawaii             1010
# 12                 Idaho             1001
# 48         West Virginia              999
# 7               Delaware              998
# 8   District of Columbia              977

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
plt.figure(figsize=(15,15))
ax=sns.heatmap(final.corr());
ax.set_title('Correlations among ACT and SAT tests in 2017 and 2018');

# %% [markdown]
# Key findings in 2017 and 2018, as well as ACT and SAT:
# 1) Scores are highly negatively correlated with participation rate.
# 2) Total/composite scores are highly correlated with sub-category tests.
# 3) SAT scores are slightly negatively correlated with ACT scores.

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(figsize=(10,10),nrows=nrows, ncols=2) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column],20) # feel free to add more settings
        ax[i].title.set_text(list_of_titles[i])
        ax[i].set_xlabel(list_of_xlabels[i])

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
# Math scores for SAT & ACT in 2017 and 2018

subplot_histograms(final, ['ACT(2017) Participation','ACT(2018) Participation','SAT(2017) Participation','SAT(2018) Participation'], ['ACT(2017) Participation','ACT(2018) Participation','SAT(2017) Participation','SAT(2018) Participation'], ['Participation rate','Participation rate','Participation rate','Participation rate'])

# %% [markdown]
# Key findings:
# 1) Data is concentrated on the extreme ends of the participation rates (0 and 1) as it may be due to mandatory test.
# 2) ACT is negative skewed while SAT is postive skewed.
# 3) Both SAT and ACT appear flat in the middle (0.1 to 0.9).

# %%
# Participation rates for SAT & ACT in 2017 and 2018

subplot_histograms(final, ['ACT(2017) Math','ACT(2018) Math','SAT(2017) Math','SAT(2018) Math'], ['ACT(2017) Math','ACT(2018) Math','SAT(2017) Math','SAT(2018) Math'], ['ACT Math Score','ACT Math Score','SAT Math Score','SAT Math Score'])

# %% [markdown]
# It appears that both SAT and ACT math scores do not follow a normal distribution.

# %%
#Reading/verbal scores for SAT & ACT

subplot_histograms(final, ['ACT(2017) Reading','ACT(2018) Reading','SAT(2017) Reading and Writing','SAT(2018) Reading and Writing'], ['ACT(2017) Reading','ACT(2018) Reading','SAT(2017) Reading and Writing','SAT(2018) Reading and Writing'], ['ACT reading score','ACT reading score','SAT reading score','SAT reading score'])

# %% [markdown]
# It appears that both SAT and ACT math scores do not follow a normal distribution.

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
#SAT vs. ACT math scores for 2017
sns.set(style="white")
ax=sns.regplot(x="ACT(2017) Reading", y="SAT(2017) Math",fit_reg=False,data=final);
ax.set_title("SAT vs. ACT math scores for 2017");

# %%
#SAT vs. ACT verbal/reading scores for 2017
sns.set(style="white")
ax=sns.regplot(x="ACT(2017) Math", y="SAT(2017) Reading and Writing",fit_reg=False,data=final);
ax.set_title("SAT vs. ACT verbal/reading scores for 2017");

# %%
#SAT vs. ACT total/composite scores for 2017
sns.set(style="white")
ax=sns.regplot(x="ACT(2017) Composite", y="SAT(2017) Total",fit_reg=False,data=final);
ax.set_title("SAT vs. ACT total/composite scores for 2017");

# %% [markdown]
# For math, reading and total/composite scores, there are weak negative correlation between SAT and ACT. This means that states that do well in one test are less likely to do well in another due to limited resources(e.g. time).

# %%
#Total scores for SAT 2017 vs. 2018
sns.set(style="white")
ax=sns.regplot(x="SAT(2018) Total", y="SAT(2017) Total",fit_reg=False,data=final);
ax.set_title("Total scores for SAT 2017 vs. 2018");

# %%
#Composite scores for ACT 2017 vs. 2018
sns.set(style="white")
ax=sns.regplot(x="ACT(2018) Composite", y="ACT(2017) Composite",fit_reg=False,data=final);
ax.set_title("Composite scores for ACT 2017 vs. 2018");

# %% [markdown]
# Both SAT and ACT had strong positive linear correlation between 2017 and 2018 scores. This means that states that have done well in previous years are likely to continue to do well in the coming year.

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
# Both tests' participation rates in 2017 and 2018

df_participation=pd.DataFrame(data=final,columns=['ACT(2017) Participation','ACT(2018) Participation','SAT(2017) Participation',
                                                  'SAT(2018) Participation']);

ax1 = sns.boxplot(x="variable", y="value", data=pd.melt(df_participation));

ax1.set_xticklabels(ax1.get_xticklabels(),rotation=30);
plt.xlabel("");
plt.ylabel("Participation rate");
plt.title("SAT and ACT participation rates in 2017 and 2018");

# %% [markdown]
# 1) Key distribution parameters across 2017 and 2018 are similar for SAT and ACT.
# 2) ACT has significant lower whisker, while SAT has significant upper whisker.  More uncertainties at higher SAT participation rates and lower ACT participation rates.
# 3) The medians are close to center.

# %%
# ACT scores in 2017 and 2018

df_ACT=pd.DataFrame(data=final,columns=['ACT(2017) English','ACT(2018) English','ACT(2017) Math','ACT(2018) Math','ACT(2017) Reading','ACT(2018) Reading',
                                        'ACT(2017) Science','ACT(2018) Science','ACT(2017) Composite','ACT(2018) Composite']);

ax1 = sns.boxplot(x="variable", y="value", data=pd.melt(df_ACT));

ax1.set_xticklabels(ax1.get_xticklabels(),rotation=90);

# %% [markdown]
# 1) Medians are not close to center as most boxplots for ACT scores are left skewed.
# 2) The level of uncertainty in ACT English is greater than other subjects.

# %%
# SAT scores in 2017 and 2018

df_SAT=pd.DataFrame(data=final,columns=['SAT(2017) Reading and Writing','SAT(2018) Reading and Writing','SAT(2017) Math','SAT(2018) Math'])

ax1 = sns.boxplot(x="variable", y="value", data=pd.melt(df_SAT));

ax1.set_xticklabels(ax1.get_xticklabels(),rotation=90);

# %% [markdown]
# 1) Medians are not close to center as most boxplots for SAT scores are left skewed.
# 2) The level of uncertainty in SAT Math is slightly greater than reading.

# %%
# SAT total scores in 2017 and 2018

df_SAT_total=pd.DataFrame(data=final,columns=['SAT(2017) Total','SAT(2018) Total'])

ax1 = sns.boxplot(x="variable", y="value", data=pd.melt(df_SAT_total));

ax1.set_xticklabels(ax1.get_xticklabels(),);

# %% [markdown]
# 1) SAT Total scores in 2017 and 2018 are highly left skewed.

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
#ACT 2017 score vs participation
sns.set(style="white")
ax=sns.regplot(x="ACT(2017) Participation", y="ACT(2017) Composite",fit_reg=False,data=final);
ax.set_title("ACT 2017 Score vs Participation");

# %%
#ACT 2018 score vs participation
sns.set(style="white")
ax=sns.regplot(x="ACT(2018) Participation", y="ACT(2018) Composite",fit_reg=False,data=final);
ax.set_title("ACT 2018 Score vs Participation");

# %%
#SAT 2017 score vs participation
sns.set(style="white")
ax=sns.regplot(x="SAT(2017) Participation", y="SAT(2017) Total" ,fit_reg=False,data=final);
ax.set_title("SAT 2017 Score vs Participation");

# %%
#SAT 2018 score vs participation
sns.set(style="white")
ax=sns.regplot(x="SAT(2018) Participation", y="SAT(2018) Total" ,fit_reg=False,data=final);
ax.set_title("SAT 2018 Score vs Participation");

# %% [markdown]
# For both SAT and ACT in 2017 and 2018, there is a strong negtive correlation between participation rate and total/composite scores.

# %%
#Participation of ACT 2017 vs SAT 2017
sns.set(style="white")
ax=sns.regplot(x="SAT(2017) Participation", y="ACT(2017) Participation" ,fit_reg=False,data=final);
ax.set_title("Participation of ACT 2017 vs SAT 2017");

# %%
#Participation of ACT 2018 vs SAT 2018
sns.set(style="white")
ax=sns.regplot(x="SAT(2018) Participation", y="ACT(2018) Participation" ,fit_reg=False,data=final);
ax.set_title("Participation of ACT 2018 vs SAT 2018");

# %% [markdown]
# In 2017 and 2018, there is a strong negtive correlation between ACT and SAT participation rates and total/composite scores.

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %%
final.describe()
# Out:
#        ACT(2017) Participation  ACT(2017) English  ACT(2017) Math  \
# count                51.000000          51.000000       51.000000
# mean                  0.652549          20.931373       21.182353
# std                   0.321408           2.353677        1.981989
# min                   0.080000          16.300000       18.000000
# 25%                   0.310000          19.000000       19.400000
# 50%                   0.690000          20.700000       20.900000
# 75%                   1.000000          23.300000       23.100000
# max                   1.000000          25.500000       25.300000
#
#        ACT(2017) Reading  ACT(2017) Science  ACT(2017) Composite  \
# count          51.000000          51.000000            51.000000
# mean           22.013725          21.450980            21.519608
# std             2.067271           1.739353             2.020695
# min            18.100000          18.200000            17.800000
# ...

# %%
from scipy.stats import skew 
import numpy as np  
import pylab as p  

# SAT(2018) Math Distribution

def dist_spread(column):
    skewness=final[column].skew()
    kurtosis=final[column].kurtosis()
    mean1=np.mean(final[column])
    mode1=stats.mode(final[column])
    median1=np.median(final[column])
    print('For {}, skewness is {}, kurtosis is {}, mean is {}, mode is {} and median is {}.'.format(column,skewness,kurtosis,mean1,mode1[0],median1))

# %%
dist_spread('SAT(2017) Participation')
dist_spread('SAT(2017) Reading and Writing')
dist_spread('SAT(2017) Math')
dist_spread('SAT(2017) Total')

dist_spread('SAT(2018) Participation')
dist_spread('SAT(2018) Reading and Writing')
dist_spread('SAT(2018) Math')
dist_spread('SAT(2018) Total')

dist_spread('ACT(2017) Participation')
dist_spread('ACT(2017) Science')
dist_spread('ACT(2017) Reading')
dist_spread('ACT(2017) Math')
dist_spread('ACT(2017) English')
dist_spread('ACT(2017) Composite')

dist_spread('ACT(2018) Participation')
dist_spread('ACT(2018) Science')
dist_spread('ACT(2018) Reading')
dist_spread('ACT(2018) Math')
dist_spread('ACT(2018) English')
dist_spread('ACT(2018) Composite')
# Out:
# For SAT(2017) Participation, skewness is 0.3464495417240935, kurtosis is -1.380694948716665, mean is 0.39803921568627454, mode is [0.03] and median is 0.38.
# For SAT(2017) Reading and Writing, skewness is 0.27269343144412217, kurtosis is -1.220371361599373, mean is 569.1176470588235, mode is [513] and median is 559.0.
# For SAT(2017) Math, skewness is 0.3650402767345614, kurtosis is -0.925843429025841, mean is 556.8823529411765, mode is [524] and median is 548.0.
# For SAT(2017) Total, skewness is 0.3109033144632309, kurtosis is -1.1054606508753468, mean is 1126.0980392156862, mode is [1005] and median is 1107.0.
# For SAT(2018) Participation, skewness is 0.13622833514139104, kurtosis is -1.5690025331937503, mean is 0.45745098039215676, mode is [0.03] and median is 0.52.
# For SAT(2018) Reading and Writing, skewness is 0.2822996833512422, kurtosis is -1.0551177173237432, mean is 563.6862745098039, mode is [513] and median is 552.0.
# ...

# %% [markdown]
# In summary, all the tests have positive skew and flat distribution.
#
# For SAT(2017) Participation, slight positive skew, flat distribution.
# For SAT(2017) Reading and Writing, slight positive skew, flat distribution.
# For SAT(2017) Math, slight positive skew, flat distribution.
# For SAT(2017) Total, slight positive skew, flat distribution.
# For SAT(2018) Participation, very slight positive skew, flat distribution.
# For SAT(2018) Reading and Writing, slight positive skew, flat distribution.
# For SAT(2018) Math, positive skew, flat distribution.
# For SAT(2018) Total, positive skew, flat distribution.
# For ACT(2017) Science, slight positive skew, flat distribution.
# For ACT(2017) Reading, slight positive skew, flat distribution.
# For ACT(2017) Math, slight positive skew, flat distribution.
# For ACT(2017) English, slight positive skew, flat distribution.
# For ACT(2017) Composite, slight positive skew, flat distribution.
# For ACT(2018) Science, slight positive skew, flat distribution.
# For ACT(2018) Reading, slight positive skew, flat distribution.
# For ACT(2018) Math, slight positive skew, flat distribution.
# For ACT(2018) English, slight positive skew, flat distribution.
# For ACT(2018) Composite, slight positive skew, flat distribution.

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# No. For all categories, the skewness and kurtosis are not zero, and their means, modes and medians are not equal.

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# For Math, they are not normally distributed due to slightly positive skewness and negative kurtosis.
#
#     For SAT(2017) Math, skewness is 0.3650402767345614, kurtosis is -0.925843429025841, mean is 556.8823529411765, mode is [524] and median is 548.0.
#     For SAT(2018) Math, skewness is 0.5304072178315771, kurtosis is -0.7561262325238918, mean is 556.2352941176471, mode is [506] and median is 544.0.
#     For ACT(2017) Math, skewness is 0.332683294922025, kurtosis is -0.9792097053651188, mean is 21.182352941176468, mode is [19.4] and median is 20.9.
#     For ACT(2018) Math, skewness is 0.2695476735535487, kurtosis is -1.1090593280003729, mean is 21.125490196078434, mode is [19.7] and median is 20.7.
#
# For Reading, they are not normally distributed due to relatively more negative kurtosis values.
#
#     For SAT(2017) Reading and Writing, skewness is 0.27269343144412217, kurtosis is -1.220371361599373, mean is 569.1176470588235, mode is [513] and median is 559.0.
#     For SAT(2018) Reading and Writing, skewness is 0.2822996833512422, kurtosis is -1.0551177173237432, mean is 563.6862745098039, mode is [513] and median is 552.0.
#     For ACT(2017) Reading, skewness is 0.2693660796931826, kurtosis is -0.9820936376105593, mean is 22.013725490196077, mode is [20.1] and median is 21.8.
#     For ACT(2018) Reading, skewness is 0.20136136090418544, kurtosis is -1.1160308434700195, mean is 22.015686274509804, mode is [24.7] and median is 21.6.
#
# For rates, they are not normally distributed due to negative kurtosis values.
#
#        For SAT(2017) Participation, skewness is 0.3464495417240936, kurtosis is -1.3806949487166649, mean is 0.39803921568627454, mode is [0.03] and median is 0.38.
#         For SAT(2018) Participation, skewness is 0.13622833514139104, kurtosis is -1.5690025331937503, mean is 0.45745098039215676, mode is [0.03] and median is 0.52.
#         For ACT(2017) Participation, skewness is -0.19798941941195083, kurtosis is -1.63197035226397, mean is 0.6525490196078431, mode is [1.] and median is 0.6900000000000001.
#         For ACT(2018) Participation, skewness is -0.02191557955297279, kurtosis is -1.7386810293202968, mean is 0.6164705882352941, mode is [1.] and median is 0.66.

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# No because all of the categories are not normal distribution. Therefore, it is difficult to infer statistical meaning from the normal distribution model.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %%
#ACT and SAT Math scores
sns.set(style="white")
ax=sns.regplot(x="ACT(2017) Math", y="SAT(2017) Math",fit_reg=False,data=final);
ax.set_title("ACT(2017) Math vs SAT(2017) Math");

# %% [markdown]
# Yes, SAT Math score is negatively correlated to ACT Math score.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code: Sharpiro-Wilk
from scipy.stats import shapiro 
sat2018_P=np.array(final['SAT(2018) Participation'])
shapiro(sat2018_P)
# Out:
# (0.856289803981781, 1.9515182430041023e-05)

# %% [markdown]
# P-value of above test for normality is 1.95x10^-5, which is smaller than 0.05. Therefore, the null hypothesis of normality is rejected and we can assume that the data are non-normally distributed.

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# The three states (1. Illinois, 2. Colorado and 3. Rhode Island) have demonstrated significant increase in their SAT participation rates from 2017 to 2018.
#
# 1) Illinois State Board of Education has ended its contract with ACT as the College Board earlier won a three-year, $14.3 million bid to give its exam to all public high school juniors in Illinois in 2016.(source: https://www.chicagotribune.com/news/ct-illinois-chooses-sat-met-20160211-story.html)
#
# 2) In Colorado, the state Department of Education announced in 2015 that a selection committee chose The College Board, makers of the SAT, over the ACT testing company, through a competitive bidding process.(source:https://chalkbeat.org/posts/co/2015/12/23/goodbye-act-hello-sat-a-significant-change-for-colorado-high-schoolers/)
#
# 3)  In 2018, the SATs and PSATs became a graduation requirement, part of the Rhode Island’s college admission test.(source:https://www.providencejournal.com/news/20181025/with-sat-required-ri-sees-jump-in-participation-decline-in-scores)

# %%
# Find the top states with greatest increase in SAT participation rate from 2017 to 2018
final['SAT_increase']=final['SAT(2018) Participation'] - final['SAT(2017) Participation']
final['ACT_increase']=final['ACT(2018) Participation'] - final['ACT(2017) Participation']
final.sort_values('SAT_increase',ascending=False)[['State','SAT(2018) Participation','SAT(2017) Participation','SAT_increase', 'ACT(2018) Participation','ACT(2017) Participation','ACT_increase']].head(5)
# Out:
#             State  SAT(2018) Participation  SAT(2017) Participation  \
# 13       Illinois                     0.99                     0.09
# 5        Colorado                     1.00                     0.11
# 39   Rhode Island                     0.97                     0.71
# 48  West Virginia                     0.28                     0.14
# 30     New Jersey                     0.82                     0.70
#
#     SAT_increase  ACT(2018) Participation  ACT(2017) Participation  \
# 13          0.90                     0.43                     0.93
# 5           0.89                     0.30                     1.00
# 39          0.26                     0.15                     0.21
# 48          0.14                     0.65                     0.69
# 30          0.12                     0.31                     0.34
#
#     ACT_increase
# 13         -0.50
# 5          -0.70
# 39         -0.06
# 48         -0.04
# 30         -0.03

# %%
# Find the top states with greatest increase in ACT participation rate from 2017 to 2018
final['ACT_drop']=final['ACT(2017) Participation']-final['ACT(2018) Participation']
final['SAT_change']=final['SAT(2018) Participation'] - final['SAT(2017) Participation']
final.sort_values('ACT_drop',ascending=False)[['State','ACT(2018) Participation','ACT(2017) Participation','ACT_drop','SAT(2018) Participation','SAT(2017) Participation','SAT_increase']].head(5)
# Out:
#        State  ACT(2018) Participation  ACT(2017) Participation  ACT_drop  \
# 5   Colorado                     0.30                     1.00      0.70
# 13  Illinois                     0.43                     0.93      0.50
# 1     Alaska                     0.33                     0.65      0.32
# 22  Michigan                     0.22                     0.29      0.07
# 9    Florida                     0.66                     0.73      0.07
#
#     SAT(2018) Participation  SAT(2017) Participation  SAT_increase
# 5                      1.00                     0.11          0.89
# 13                     0.99                     0.09          0.90
# 1                      0.43                     0.38          0.05
# 22                     1.00                     1.00          0.00
# 9                      0.56                     0.83         -0.27

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# Conclusions
#
# 1) ACT is a competitor of SAT.
# 2) 100% participation rates are observed in states that mandate either SAT or ACT.
# 3) The participation rates for ACT and SAT are highly dependent on the States that usually engage SAT and ACT through the government bidding process.
# 4) States without mandatory SAT or ACT requirements are likely to have participation rates higher than 50%.
#
# Recommendations
#
# The College Board could target Wisconsin, given the following reasons:
#     1) Wisconsin mandates student from public schools to take ACT - potential to achieve 100%
#     2) Wisconsin had the third lowest participation rate (0.03) in 2018
#     3) Wisconsin's public high school student population was larger than Iowa, North Dakota and Wyoming (source: https://educationdata.org/number-of-public-schools/)
#
# Win contracts with the Wisconsin Department of Education to make SAT mandatory, the College Board can aim undercut ACT when Wisconsin’s contract with ACT ends.
#     1) Wisconsin state is likely to prioritise cost reduction over the next few years as the US government has only approved a state budget which was half the amount of what was requested by Wisconsin in 2019 (source: https://www.wuwm.com/post/budget-compromise-gives-wisconsin-schools-half-funding-boost-evers-wanted#stream/0)
#     2) Assumptions: Wisconsin’s contract duration with ACT will end in 2020 and Wisconsin will continue to mandate SAT/ACT
#     Other considerations include offering free SAT to students
