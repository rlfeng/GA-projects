# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.metrics import roc_auc_score, roc_curve, confusion_matrix, accuracy_score, f1_score, precision_score, recall_score,auc

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from statistics import median, mean
from math import ceil

# %%
weather=pd.read_csv('./weather.csv/weather.csv')

# %%
#Drop the following columns from weather Water1: All rows are missing data CodeSum: Contains information on weather conditions which have been captured in other columns SnowFall: Data are only available for station 1 and most of them are zeros (1459 out of 1472).
weather.drop(columns=['Water1','CodeSum','SnowFall', 'Depth'], inplace=True)

# %%
#Impute missing 'M' and trace 'T' data for Tavg, WetBulb, StnPressure, SeaLevel, AvgSpeed, PrecipTotal

weather['Tavg']=(weather.Tmax+weather.Tmin)/2
weather['Tavg']=weather['Tavg'].apply(np.ceil).astype(int)

weather['WetBulb'].replace('M',np.nan, inplace=True)
weather['WetBulb']=weather['WetBulb'].astype(float)
weather['WetBulb'].replace('NaN',mean(weather['WetBulb']), inplace=True)

weather['StnPressure'].replace('M',np.nan, inplace=True)
weather['StnPressure']=weather['StnPressure'].astype(float)
weather['StnPressure'].replace('NaN',mean(weather['StnPressure']), inplace=True)

weather['SeaLevel'].replace('M',np.nan, inplace=True)
weather['SeaLevel']=weather['SeaLevel'].astype(float)
weather['SeaLevel'].replace('NaN',mean(weather['SeaLevel']), inplace=True)

weather['AvgSpeed'].replace('M',np.nan, inplace=True)
weather['AvgSpeed']=weather['AvgSpeed'].astype(float)
weather['AvgSpeed'].replace('NaN',mean(weather['AvgSpeed']), inplace=True)

weather['PrecipTotal'].replace('  T',0.00, inplace=True)
weather['PrecipTotal'].replace('M',np.nan, inplace=True)
weather['PrecipTotal']=weather['PrecipTotal'].astype(float)
weather['PrecipTotal'].replace('NaN',mean(weather['PrecipTotal']), inplace=True)

# %%
# Calculate Heat and Cool parameters from Tavg

weather['heat']=weather['Tavg'].apply(lambda x: 0 if x>64 else 65-x)
weather.replace('Heat', 'heat', inplace=True)

weather['cool']=weather['Tavg'].apply(lambda x: 0 if x<65 else x-65)
weather.replace('Cool', 'cool', inplace=True)

# %%
# Average the common variables in Stations 1 and 2

weather_final=weather.groupby('Date')['Tavg', 'Tmax', 'Tmin', 'DewPoint', 'WetBulb', 'heat', 'cool', 'PrecipTotal', 'StnPressure', 
                                      'SeaLevel','ResultSpeed','ResultDir','AvgSpeed'].mean()

# %%
# Feature engineering for daylight hours

sun=weather[weather.Station==1][['Date','Sunset','Sunrise']]
sun['time_diff']=sun.apply(lambda x: int(x.Sunset)-int(x.Sunrise),axis=1)
sun['sun_period']=sun.time_diff.map(lambda x:int(str(x)[:2])+int(str(x)[-2:])/60)

weather_final=weather_final.merge(sun, on=['Date'], how='left')
weather_final.drop(columns=['Sunset','Sunrise','time_diff'], inplace=True)

# %%
# Merge Station 1's Depart data with weather_final

depart=weather[weather.Station==1][['Date','Depart']]
depart['Depart']=depart['Depart'].astype(int)
weather_final=weather_final.merge(depart, on=['Date'], how='left')

# %%
weather_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1472 entries, 0 to 1471
# Data columns (total 16 columns):
# Date           1472 non-null object
# Tavg           1472 non-null float64
# Tmax           1472 non-null float64
# Tmin           1472 non-null float64
# DewPoint       1472 non-null float64
# WetBulb        1472 non-null float64
# heat           1472 non-null float64
# cool           1472 non-null float64
# PrecipTotal    1472 non-null float64
# StnPressure    1471 non-null float64
# SeaLevel       1472 non-null float64
# ResultSpeed    1472 non-null float64
# ResultDir      1472 non-null float64
# AvgSpeed       1472 non-null float64
# sun_period     1472 non-null float64
# Depart         1472 non-null int32
# dtypes: float64(14), int32(1), object(1)
# memory usage: 189.8+ KB

# %% [markdown]
# # EDA on weather

# %%
weather_final_corr=weather_final.corr()
mask = np.triu(np.ones_like(weather_final_corr, dtype=np.bool))
sns.heatmap(weather_final_corr, cmap="PiYG",mask=mask)

# %%
# Convert Date to month, year
weather_final['year']=pd.to_datetime(weather_final['Date']).dt.strftime('%Y')#.astype(int)
weather_final['month']=pd.to_datetime(weather_final['Date']).dt.strftime('%m')#.astype(int)

# %%
# Weather variation over months
fig=plt.subplots(figsize=(20,15))
plt.subplot(3,2,1),sns.barplot('month','Tavg',data=weather_final,hue='year')
plt.legend().set_visible(False)
plt.subplot(3,2,2),sns.barplot('month','AvgSpeed',data=weather_final,hue='year')
plt.legend().set_visible(False)
plt.subplot(3,2,3),sns.barplot('month','DewPoint',data=weather_final,hue='year')
plt.legend().set_visible(False)
plt.subplot(3,2,4),sns.barplot('month','sun_period',data=weather_final,hue='year')
plt.legend().set_visible(False)
plt.subplot(3,2,5),sns.barplot('month','StnPressure',data=weather_final,hue='year') 
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05),
          fancybox=True, shadow=True, ncol=5)
plt.subplot(3,2,6),sns.barplot('month','PrecipTotal',data=weather_final,hue='year')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05),
          fancybox=True, shadow=True, ncol=5)

# %%
weather_final.drop(columns=['year','month'], inplace=True)

# %%
weather_final.to_csv('C:/Users/frl/Desktop/DSI13/MyDSI_11Feb/Projects/project_4/weather_final.csv',index=False)

# %%
weather_final
# Out:
#             Date  Tavg  Tmax  Tmin  DewPoint  WetBulb  heat  cool  \
# 0     2007-05-01  67.5  83.5  51.0      51.0     56.5   0.0   2.5
# 1     2007-05-02  51.5  59.5  42.5      42.0     47.0  13.5   0.0
# 2     2007-05-03  57.0  66.5  47.0      40.0     49.0   8.0   0.0
# 3     2007-05-04  61.5  72.0  50.0      41.5     50.0   3.5   0.0
# 4     2007-05-05  60.0  66.0  53.5      38.5     49.5   5.0   0.0
# 5     2007-05-06  59.5  68.0  50.5      30.0     46.0   5.5   0.0
# 6     2007-05-07  66.0  83.5  48.5      40.0     53.5   0.0   1.0
# 7     2007-05-08  69.0  81.0  57.0      57.5     62.5   0.0   4.0
# 8     2007-05-09  69.5  76.5  62.0      59.5     63.0   0.0   4.5
# 9     2007-05-10  70.5  83.5  57.5      52.0     60.5   0.0   5.5
# 10    2007-05-11  61.0  71.5  50.0      43.0     51.0   4.0   0.0
# 11    2007-05-12  55.5  64.5  46.5      36.5     46.0   9.5   0.0
# 12    2007-05-13  56.5  69.0  43.5      32.5     46.0   8.5   0.0
# 13    2007-05-14  72.5  90.0  55.0      46.0     58.5   0.0   7.5
# 14    2007-05-15  69.0  81.0  56.5      56.0     61.0   0.0   4.0
# 15    2007-05-16  55.0  65.0  44.5      42.5     47.5  10.0   0.0
# 16    2007-05-17  53.0  61.5  43.5      32.0     43.0  12.0   0.0
# 17    2007-05-18  57.0  70.5  42.5      30.5     46.5   8.0   0.0
# 18    2007-05-19  68.0  80.0  56.0      38.0     53.0   0.0   3.0
# 19    2007-05-20  56.5  69.0  43.5      40.5     44.5   8.5   0.0
# 20    2007-05-21  62.5  79.5  45.0      50.0     56.5   2.5   0.0
# 21    2007-05-22  72.5  87.0  57.5      45.0     58.0   0.0   7.5
# 22    2007-05-23  76.5  89.0  63.0      48.5     61.0   0.0  11.5
# 23    2007-05-24  76.5  88.0  64.5      53.5     63.0   0.0  11.5
# 24    2007-05-25  62.5  68.0  56.5      45.0     53.0   2.5   0.0
# 25    2007-05-26  58.5  67.5  49.5      55.0     56.5   6.5   0.0
# 26    2007-05-27  66.5  75.0  58.0      48.0     56.5   0.0   1.5
# 27    2007-05-28  65.0  77.5  52.0      48.0     56.5   0.0   0.0
# 28    2007-05-29  75.5  88.0  62.5      58.5     65.5   0.0  10.5
# 29    2007-05-30  78.5  88.0  68.0      57.5     65.5   0.0  13.5
# ...          ...   ...   ...   ...       ...      ...   ...   ...
# 1442  2014-10-02  69.5  73.5  64.5      62.0     64.0   0.0   4.5
# 1443  2014-10-03  55.5  66.5  44.5      46.0     50.5   9.5   0.0
# 1444  2014-10-04  42.0  48.0  36.0      34.5     40.0  23.0   0.0
# 1445  2014-10-05  47.5  55.5  39.5      35.5     43.0  17.5   0.0
# 1446  2014-10-06  54.0  62.0  45.0      39.0     46.0  11.0   0.0
# 1447  2014-10-07  58.0  67.5  48.5      44.0     50.5   7.0   0.0
# 1448  2014-10-08  56.5  66.0  46.0      35.5     47.0   8.5   0.0
# 1449  2014-10-09  55.0  63.0  46.5      35.0     45.0  10.0   0.0
# 1450  2014-10-10  50.5  58.5  41.5      39.5     45.0  14.5   0.0
# 1451  2014-10-11  49.0  59.5  38.0      35.0     43.0  16.0   0.0
# 1452  2014-10-12  53.0  63.5  41.5      43.0     48.5  12.0   0.0
# 1453  2014-10-13  63.5  69.0  57.5      59.5     61.0   1.5   0.0
# 1454  2014-10-14  60.0  66.0  53.0      58.0     59.0   5.0   0.0
# 1455  2014-10-15  54.5  56.5  51.5      52.0     52.5  10.5   0.0
# 1456  2014-10-16  54.5  57.0  51.5      50.5     52.0  10.5   0.0
# 1457  2014-10-17  55.5  62.5  48.5      47.0     51.0   9.5   0.0
# 1458  2014-10-18  44.5  51.0  37.5      39.0     43.0  20.5   0.0
# 1459  2014-10-19  45.5  55.5  34.5      39.0     43.5  19.5   0.0
# 1460  2014-10-20  57.0  65.5  48.0      45.0     50.0   8.0   0.0
# 1461  2014-10-21  50.5  53.5  47.0      40.0     45.0  14.5   0.0
# 1462  2014-10-22  48.0  56.0  39.0      38.0     43.5  17.0   0.0
# 1463  2014-10-23  50.0  60.5  38.5      40.5     46.0  15.0   0.0
# 1464  2014-10-24  60.5  67.5  53.0      47.0     52.5   4.5   0.0
# 1465  2014-10-25  62.5  73.5  50.5      40.5     51.5   2.5   0.0
# 1466  2014-10-26  54.0  65.0  43.0      32.5     44.5  11.0   0.0
# 1467  2014-10-27  65.5  78.0  52.5      51.5     58.5   0.5   1.0
# 1468  2014-10-28  57.0  67.0  46.5      39.0     47.5   8.0   0.0
# 1469  2014-10-29  44.0  49.0  38.0      33.0     41.0  21.0   0.0
# 1470  2014-10-30  43.5  52.0  34.5      34.5     41.0  21.5   0.0
# 1471  2014-10-31  41.0  48.0  33.5      27.0     34.5  24.0   0.0
#
#       PrecipTotal  StnPressure  SeaLevel  ResultSpeed  ResultDir  AvgSpeed  \
# 0           0.000       29.140    29.820         2.20       26.0      9.40
# 1           0.000       29.410    30.085        13.15        3.0     13.40
# 2           0.000       29.425    30.120        12.30        6.5     12.55
# 3           0.000       29.335    30.045        10.25        7.5     10.60
# 4           0.000       29.430    30.095        11.45        7.0     11.75
# 5           0.000       29.595    30.285        14.10       10.5     14.75
# 6           0.000       29.410    30.120         8.55       17.5     10.20
# 7           0.000       29.325    30.025         2.60        9.5      5.60
# 8           0.075       29.245    29.935         3.90        8.0      6.05
# 9           0.000       29.230    29.915         1.35       13.0      4.00
# 10          0.000       29.360    30.035        11.50       19.5     12.85
# 11          0.000       29.515    30.195        12.55        2.0     12.95
# 12          0.000       29.520    30.240         6.50       12.5      7.85
# 13          0.000       29.270    29.975        15.50       21.0     15.95
# 14          0.490       29.160    29.835         8.10       26.0     11.55
# 15          0.105       29.360    30.030         7.90       36.0     12.00
# 16          0.000       29.585    30.270        11.10        2.0     11.75
# 17          0.000       29.565    30.255         4.40       23.5      6.50
# 18          0.000       29.375    30.080        11.10       23.5     11.40
# 19          0.090       29.410    30.110         9.50        3.5     10.20
# 20          0.000       29.360    30.055         6.30       10.5      8.00
# 21          0.000       29.375    30.055        10.05       17.0     10.40
# 22          0.000       29.430    30.100        11.15       18.5     11.50
# 23          0.010       29.440    30.105        14.35       20.5     16.25
# 24          0.045       29.540    30.235         4.70        5.0      8.50
# 25          0.645       29.390    30.105         2.65       16.0      7.50
# 26          0.060       29.375    30.055         8.55       25.0      9.35
# 27          0.000       29.460    30.145         4.75        9.0      5.25
# 28          0.000       29.415    30.100         5.80       17.0      6.95
# 29          0.000       29.345    30.035        10.00       18.0     10.35
# ...           ...          ...       ...          ...        ...       ...
# 1442        0.520       29.065    29.780         7.20       17.0      7.90
# 1443        0.865       28.985    29.665        14.55       28.0     16.00
# 1444        0.055       29.035    29.730        13.55       25.5     13.65
# 1445        0.005       28.985    29.690         9.30       23.0      9.85
# 1446        0.010       28.920    29.615         8.70       24.0      9.65
# 1447        0.000       29.030    29.695        10.05       24.5     11.60
# 1448        0.000       29.305    29.970        10.85       27.0     11.25
# 1449        0.000       29.410    30.090         3.40       19.0      6.05
# 1450        0.000       29.460    30.160         5.75        2.0      6.70
# 1451        0.000       29.500    30.200         3.15        8.0      4.60
# 1452        0.010       29.275    30.000         8.70       14.0      9.50
# 1453        0.540       29.000    29.730         7.60       14.5      9.00
# 1454        0.915       28.860    29.545         2.65       11.0      9.40
# 1455        0.060       29.075    29.745         9.45       35.0      9.80
# 1456        0.000       29.055    29.770         4.75       24.5      7.90
# 1457        0.005       29.020    29.690        10.90       28.5     12.95
# 1458        0.015       29.415    30.080         7.90       34.0      8.95
# 1459        0.000       29.350    30.080         8.30       21.0      8.60
# 1460        0.005       29.200    29.900         4.80       32.0      9.20
# 1461        0.000       29.485    30.155        10.90       18.5     11.50
# 1462        0.000       29.590    30.300         2.95        9.5      4.95
# 1463        0.000       29.425    30.155         7.70       19.0      8.10
# 1464        0.000       29.280    30.000         4.65       22.0      5.80
# 1465        0.000       29.240    29.925        10.05       28.5     10.65
# 1466        0.000       29.245    29.950         1.25        8.0      5.60
# 1467        0.010       28.960    29.665        12.35       19.0     13.25
# 1468        0.015       29.190    29.850        14.40       26.0     15.10
# 1469        0.000       29.390    30.065         9.00       29.0      9.45
# 1470        0.000       29.375    30.095         5.50       23.5      6.00
# 1471        0.035       29.515    30.200        22.15       34.0     22.75
#
#       sun_period  Depart
# 0      14.016667      14
# 1      14.050000      -3
# 2      14.083333       2
# 3      14.133333       4
# 4      14.166667       5
# 5      14.216667       4
# 6      14.250000      10
# 7      14.300000      12
# 8      14.333333      13
# 9      14.366667      14
# 10     14.400000       4
# 11     15.100000      -2
# 12     15.133333      -2
# 13     15.166667      15
# 14     15.200000      11
# 15     15.233333      -4
# 16     15.266667      -6
# 17     15.300000      -3
# 18     15.333333       8
# 19     15.366667      -5
# 20     15.400000       1
# 21     15.433333      10
# 22     15.450000      14
# 23     15.483333      14
# 24     15.516667       1
# 25     15.550000      -5
# 26     15.566667       4
# 27     15.583333       2
# 28     15.600000      10
# 29     15.633333      13
# ...          ...     ...
# 1442   12.383333      10
# 1443   12.333333      -3
# 1444   12.283333     -16
# 1445   12.233333     -11
# 1446   12.183333      -4
# 1447   12.150000       1
# 1448   12.100000      -1
# 1449   12.050000      -2
# 1450   12.016667      -6
# 1451   11.966667      -6
# 1452   11.250000      -3
# 1453   11.200000       9
# 1454   11.150000       6
# 1455   11.116667       0
# 1456   11.066667       1
# 1457   11.016667       3
# 1458   11.650000      -8
# 1459   11.600000      -7
# 1460   11.550000       6
# 1461   11.500000      -1
# 1462   10.800000      -4
# 1463   10.750000      -1
# 1464   10.716667      11
# 1465   10.666667      13
# 1466   10.616667       5
# 1467   10.583333      16
# 1468   10.533333      10
# 1469   10.500000      -4
# 1470   10.450000      -4
# 1471   10.400000      -6
#
# [1472 rows x 16 columns]
